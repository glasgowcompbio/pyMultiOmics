# %%
pip install pyMultiOmics
# Out:
# Requirement already satisfied: pyMultiOmics in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: numpy in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (1.21.1)
# Requirement already satisfied: tzlocal in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (2.1)
# Requirement already satisfied: pillow in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (8.3.1)
# Requirement already satisfied: matplotlib in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (3.4.2)
# Requirement already satisfied: jupyterlab in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (3.1.4)
# Requirement already satisfied: networkx in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (2.6.2)
# Requirement already satisfied: bioservices in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (1.7.12)
# Requirement already satisfied: tqdm in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (4.62.0)
# Requirement already satisfied: requests in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (2.26.0)
# Requirement already satisfied: statsmodels in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (0.12.2)
# Requirement already satisfied: plotly in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (5.1.0)
# Requirement already satisfied: scipy in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (1.7.1)
# Requirement already satisfied: seaborn in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (0.11.1)
# Requirement already satisfied: neo4j-driver==1.7.6 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (1.7.6)
# Requirement already satisfied: pals-pathway in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (1.5.2)
# Requirement already satisfied: pandas in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (1.3.1)
# Requirement already satisfied: scikit-learn in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (0.24.2)
# Requirement already satisfied: loguru in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pyMultiOmics) (0.5.3)
# Requirement already satisfied: neobolt~=1.7.15 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from neo4j-driver==1.7.6->pyMultiOmics) (1.7.17)
# Requirement already satisfied: neotime~=1.7.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from neo4j-driver==1.7.6->pyMultiOmics) (1.7.4)
# Requirement already satisfied: six in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from neotime~=1.7.1->neo4j-driver==1.7.6->pyMultiOmics) (1.16.0)
# Requirement already satisfied: pytz in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from neotime~=1.7.1->neo4j-driver==1.7.6->pyMultiOmics) (2021.1)
# Requirement already satisfied: appdirs in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (1.4.4)
# Requirement already satisfied: colorlog in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (5.0.1)
# Requirement already satisfied: grequests in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (0.6.0)
# Requirement already satisfied: suds-jurko in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (0.6)
# Requirement already satisfied: wrapt in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (1.12.1)
# Requirement already satisfied: beautifulsoup4 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (4.9.3)
# Requirement already satisfied: easydev>=0.9.36 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (0.11.1)
# Requirement already satisfied: lxml in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (4.6.3)
# Requirement already satisfied: xmltodict in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (0.12.0)
# Requirement already satisfied: requests-cache in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bioservices->pyMultiOmics) (0.7.3)
# Requirement already satisfied: pexpect in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from easydev>=0.9.36->bioservices->pyMultiOmics) (4.8.0)
# Requirement already satisfied: colorama in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from easydev>=0.9.36->bioservices->pyMultiOmics) (0.4.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from beautifulsoup4->bioservices->pyMultiOmics) (2.2.1)
# Requirement already satisfied: gevent in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from grequests->bioservices->pyMultiOmics) (21.8.0)
# Requirement already satisfied: zope.interface in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from gevent->grequests->bioservices->pyMultiOmics) (5.4.0)
# Requirement already satisfied: setuptools in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from gevent->grequests->bioservices->pyMultiOmics) (57.4.0)
# Requirement already satisfied: zope.event in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from gevent->grequests->bioservices->pyMultiOmics) (4.5.0)
# Requirement already satisfied: greenlet<2.0,>=1.1.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from gevent->grequests->bioservices->pyMultiOmics) (1.1.1)
# Requirement already satisfied: nbclassic~=0.2 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (0.3.1)
# Requirement already satisfied: jupyter-server~=1.4 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (1.10.2)
# Requirement already satisfied: jinja2>=2.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (3.0.1)
# Requirement already satisfied: jupyterlab-server~=2.3 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (2.6.2)
# Requirement already satisfied: ipython in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (7.26.0)
# Requirement already satisfied: jupyter-core in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (4.7.1)
# Requirement already satisfied: packaging in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (21.0)
# Requirement already satisfied: tornado>=6.1.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab->pyMultiOmics) (6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jinja2>=2.1->jupyterlab->pyMultiOmics) (2.0.1)
# Requirement already satisfied: Send2Trash in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (1.8.0)
# Requirement already satisfied: ipython-genutils in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.2.0)
# Requirement already satisfied: prometheus-client in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.11.0)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (5.0.5)
# Requirement already satisfied: requests-unixsocket in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.2.0)
# Requirement already satisfied: jupyter-client>=6.1.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (6.1.12)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (3.3.0)
# Requirement already satisfied: argon2-cffi in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (22.2.1)
# Requirement already satisfied: nbformat in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (5.1.3)
# Requirement already satisfied: nbconvert in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (6.1.0)
# Requirement already satisfied: websocket-client in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (1.1.1)
# Requirement already satisfied: terminado>=0.8.3 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.10.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (3.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (2.8.2)
# Requirement already satisfied: json5 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab->pyMultiOmics) (0.9.6)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab->pyMultiOmics) (3.2.0)
# Requirement already satisfied: babel in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab->pyMultiOmics) (2.9.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab->pyMultiOmics) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab->pyMultiOmics) (21.2.0)
# Requirement already satisfied: notebook<7 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbclassic~=0.2->jupyterlab->pyMultiOmics) (6.4.2)
# Requirement already satisfied: ipykernel in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab->pyMultiOmics) (6.0.3)
# Requirement already satisfied: ptyprocess in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (1.14.6)
# Requirement already satisfied: pycparser in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (2.20)
# Requirement already satisfied: appnope in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab->pyMultiOmics) (0.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab->pyMultiOmics) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab->pyMultiOmics) (1.4.1)
# Requirement already satisfied: pygments in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipython->jupyterlab->pyMultiOmics) (2.9.0)
# Requirement already satisfied: backcall in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipython->jupyterlab->pyMultiOmics) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipython->jupyterlab->pyMultiOmics) (0.7.5)
# Requirement already satisfied: decorator in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipython->jupyterlab->pyMultiOmics) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipython->jupyterlab->pyMultiOmics) (3.0.19)
# Requirement already satisfied: jedi>=0.16 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipython->jupyterlab->pyMultiOmics) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyterlab->pyMultiOmics) (0.8.2)
# Requirement already satisfied: wcwidth in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab->pyMultiOmics) (0.2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from matplotlib->pyMultiOmics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from matplotlib->pyMultiOmics) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from matplotlib->pyMultiOmics) (2.4.7)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.5.3)
# Requirement already satisfied: defusedxml in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.1.2)
# Requirement already satisfied: testpath in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.5.0)
# Requirement already satisfied: bleach in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.3)
# Requirement already satisfied: async-generator in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (1.5.1)
# Requirement already satisfied: webencodings in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab->pyMultiOmics) (0.5.1)
# Requirement already satisfied: streamlit in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pals-pathway->pyMultiOmics) (0.86.0)
# Requirement already satisfied: gseapy==0.9.16 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pals-pathway->pyMultiOmics) (0.9.16)
# Requirement already satisfied: html5lib in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from gseapy==0.9.16->pals-pathway->pyMultiOmics) (1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from plotly->pyMultiOmics) (8.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from requests->pyMultiOmics) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from requests->pyMultiOmics) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from requests->pyMultiOmics) (2021.5.30)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from requests-cache->bioservices->pyMultiOmics) (1.4.3)
# Requirement already satisfied: pyyaml>=5.4 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from requests-cache->bioservices->pyMultiOmics) (5.4.1)
# Requirement already satisfied: itsdangerous>=2.0.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from requests-cache->bioservices->pyMultiOmics) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from scikit-learn->pyMultiOmics) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from scikit-learn->pyMultiOmics) (1.0.1)
# Requirement already satisfied: patsy>=0.5 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from statsmodels->pyMultiOmics) (0.5.1)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (3.17.3)
# Requirement already satisfied: gitpython!=3.1.19 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (3.1.18)
# Requirement already satisfied: validators in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (0.18.2)
# Requirement already satisfied: click<8.0,>=7.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (7.1.2)
# Requirement already satisfied: cachetools>=4.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (4.2.2)
# Requirement already satisfied: astor in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (0.8.1)
# Requirement already satisfied: pyarrow in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (5.0.0)
# Requirement already satisfied: base58 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (2.1.0)
# Requirement already satisfied: toml in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (0.10.2)
# Requirement already satisfied: altair>=3.2.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (4.1.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (0.6.2)
# Requirement already satisfied: blinker in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from streamlit->pals-pathway->pyMultiOmics) (1.4)
# Requirement already satisfied: toolz in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from altair>=3.2.0->streamlit->pals-pathway->pyMultiOmics) (0.11.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from gitpython!=3.1.19->streamlit->pals-pathway->pyMultiOmics) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit->pals-pathway->pyMultiOmics) (4.0.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit->pals-pathway->pyMultiOmics) (7.6.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->pals-pathway->pyMultiOmics) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/wangkeqing/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->pals-pathway->pyMultiOmics) (3.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyMultiOmics.mapping import Mapper

species_name = DANIO_RERIO
m = Mapper(species_name) \
        .set_gene(gene_data, gene_design) \
        .set_protein(protein_data, protein_design) \
        .set_compound(compound_data, compound_design) \
        .build()
# Out:
# 2021-08-11 10:13:36.474 | WARNING  | pyMultiOmics.reactome:get_neo4j_driver:14 - Using a default neo4j server: bolt://localhost:7687
# 2021-08-11 10:13:36.475 | WARNING  | pyMultiOmics.reactome:get_neo4j_driver:19 - Using a default neo4j username or password: neo4j
# 2021-08-11 10:13:36.633 | WARNING  | pyMultiOmics.reactome:get_neo4j_driver:27 - Failed to connect to graph database: Failed to establish connection to ('127.0.0.1', 7687) (reason [Errno 61] Connection refused)
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neobolt/direct.py in _connect(resolved_address, **config)
#     830         log_debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 831         s.connect(resolved_address)
#     832         s.settimeout(t)
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ServiceUnavailable                        Traceback (most recent call last)
# /var/folders/yq/_9m5lcj937x4nw9cmtz2jq800000gn/T/ipykernel_38488/1715126169.py in <module>
# ----> 1 from pyMultiOmics.mapping import Mapper
#       2
#       3 species_name = DANIO_RERIO
#       4 m = Mapper(species_name) \
#       5         .set_gene(gene_data, gene_design) \
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/pyMultiOmics/mapping.py in <module>
#       9     COMPOUND_DATABASE_CHEBI, MAPPING, PKS, IDS, NA, GENES_TO_PROTEINS, PROTEINS_TO_REACTIONS, COMPOUNDS_TO_REACTIONS, \
#      10     REACTIONS_TO_PATHWAYS
# ---> 11 from .functions import reactome_mapping
#      12 from .query import QueryBuilder, Connected
#      13
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/pyMultiOmics/functions.py in <module>
#      18     FC_COL_PREFIX, SAMPLE_COL, DATA_DIR, CHEBI_RELATION_TSV
#      19 from .metadata import get_gene_names, get_compound_metadata, clean_label
# ---> 20 from .reactome import ensembl_to_uniprot, uniprot_to_reaction, compound_to_reaction, \
#      21     reaction_to_pathway, reaction_to_uniprot, reaction_to_compound, uniprot_to_ensembl
#      22
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/pyMultiOmics/reactome.py in <module>
#      29
#      30
# ---> 31 driver = get_neo4j_driver()
#      32
#      33
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/pyMultiOmics/reactome.py in get_neo4j_driver()
#      26     except Exception as e:
#      27         logger.warning('Failed to connect to graph database: %s' % str(e))
# ---> 28         raise e
#      29
#      30
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/pyMultiOmics/reactome.py in get_neo4j_driver()
#      20
#      21     try:
# ---> 22         neo4j_driver = GraphDatabase.driver(NEO4J_SERVER,
#      23                                             auth=basic_auth(NEO4J_USER, NEO4J_PASSWORD))
#      24         logger.info('Created graph database driver for %s (%s)' % (NEO4J_SERVER, NEO4J_USER))
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neo4j/__init__.py in driver(cls, uri, **config)
#     118         :class:`.Driver` subclass instance directly.
#     119         """
# --> 120         return Driver(uri, **config)
#     121
#     122
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     159         for subclass in Driver.__subclasses__():
#     160             if parsed_scheme in subclass.uri_schemes:
# --> 161                 return subclass(uri, **config)
#     162         raise ValueError("URI scheme %r not supported" % parsed.scheme)
#     163
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     233
#     234         pool = ConnectionPool(connector, instance.address, **config)
# --> 235         pool.release(pool.acquire())
#     236         instance._pool = pool
#     237         instance._max_retry_time = config.get("max_retry_time", default_config["max_retry_time"])
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neobolt/direct.py in acquire(self, access_mode)
#     713
#     714     def acquire(self, access_mode=None):
# --> 715         return self.acquire_direct(self.address)
#     716
#     717
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neobolt/direct.py in acquire_direct(self, address)
#     606                 if can_create_new_connection:
#     607                     try:
# --> 608                         connection = self.connector(address, error_handler=self.connection_error_handler)
#     609                     except ServiceUnavailable:
#     610                         self.remove(address)
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neo4j/__init__.py in connector(address, **kwargs)
#     230
#     231         def connector(address, **kwargs):
# --> 232             return connect(address, **dict(config, **kwargs))
#     233
#     234         pool = ConnectionPool(connector, instance.address, **config)
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neobolt/direct.py in connect(address, **config)
#     970         raise ServiceUnavailable("Failed to resolve addresses for %s" % address)
#     971     else:
# --> 972         raise last_error
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neobolt/direct.py in connect(address, **config)
#     960         try:
#     961             host = address[0]
# --> 962             s = _connect(resolved_address, **config)
#     963             s, der_encoded_server_certificate = _secure(s, host, security_plan.ssl_context, **config)
#     964             connection = _handshake(s, address, der_encoded_server_certificate, **config)
#
# ~/.local/share/virtualenvs/pyMultiOmics-hFnbBj-T/lib/python3.8/site-packages/neobolt/direct.py in _connect(resolved_address, **config)
#     841         log_debug("[#0000]  C: <CLOSE> %s", resolved_address)
#     842         s.close()
# --> 843         raise ServiceUnavailable("Failed to establish connection to {!r} (reason {})".format(resolved_address, error))
#     844     else:
#     845         return s
#
# ServiceUnavailable: Failed to establish connection to ('127.0.0.1', 7687) (reason [Errno 61] Connection refused)
